# %%
# %matplotlib inline 
import Simulator.market_simulator as msim

# %%
sim = msim.MarketSim("sim_1", "Orange Market")
sim.build_market()
sim.show_market()
sim.sim_period(100)
# Out:
# Market Participants
# -------------------
# BUYERS
# ------
# buyer buyer 1 has values [192, 89, 82]
# buyer buyer 2 has values [68, 60, 11]
# buyer buyer 3 has values [199, 165, 77]
# buyer buyer 4 has values [161, 80, 70]
# --------
# SELLERS
# -------
# seller seller 1 has costs [31, 173, 177]
# seller seller 2 has costs [29, 157, 198]
# seller seller 3 has costs [48, 59, 95]
# seller seller 4 has costs [56, 99, 117]
# When Orange Market is in equilibrium we have:
# equilibrium price    = 82 - 89
# equilibrium quantity = 5
# maximum surplus      = 583
#
#
#  Order Book for Orange Market
# 1 start bid 0:Orange Market
# 2 start ask 999:Orange Market
# 3 standing bid 12:buyer 2
# 4 standing ask 779:seller 4
# 5 standing bid 26:buyer 1
# 6 standing bid 152:buyer 3
# 7 standing bid 156:buyer 3
# 8 standing ask 220:seller 1
# 9 standing ask 195:seller 4
# 10 contract ask 149:seller 3
# 11 start bid 0:Orange Market
# 12 start ask 999:Orange Market
# 13 standing ask 997:seller 2
# ...

# %%
import Tournament.tournament as tournament

tourn = tournament.Tournament("tournament_name", 5000, 100)
tourn.eval_tournament()
# Out:
# Median Actual Surplus: 523.0
# Mean Actual Surplus: 525.5534
# Median Efficiency: 97.07981026369333
# Mean Efficiency: 95.37788395615713
