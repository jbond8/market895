# %%
# %matplotlib inline 
import market_simulator as msim

# %%
sim = msim.MarketSim("sim_1", "Orange Market")
sim.build_market()
sim.show_market()
sim.sim_period(100)
# Out:
# Market Participants
# -------------------
# BUYERS
# ------
# buyer buyer 1 has values [185, 179, 166]
# buyer buyer 2 has values [100, 99, 96]
# buyer buyer 3 has values [163, 147, 110]
# buyer buyer 4 has values [186, 145, 89]
# --------
# SELLERS
# -------
# seller seller 1 has costs [38, 192, 199]
# seller seller 2 has costs [91, 176, 178]
# seller seller 3 has costs [32, 55, 110]
# seller seller 4 has costs [81, 118, 161]
# When Orange Market is in equilibrium we have:
# equilibrium price    = 118 - 145
# equilibrium quantity = 7
# maximum surplus      = 646
#
#
#  Order Book for Orange Market
# 1 start bid 0:Orange Market
# 2 start ask 999:Orange Market
# 3 standing ask 304:seller 2
# 4 standing ask 152:seller 2
# 5 standing ask 105:seller 2
# 6 standing bid 44:buyer 1
# 7 standing bid 89:buyer 2
# 8 contract bid 155:buyer 4
# 9 start bid 0:Orange Market
# 10 start ask 999:Orange Market
# 11 standing bid 89:buyer 3
# 12 standing ask 821:seller 3
# 13 standing ask 122:seller 1
# ...
