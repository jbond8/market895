# %%
# %matplotlib inline 
import market_simulator as msim

# %%
sim = msim.MarketSim("sim_1", "Orange Market")
sim.build_market()
sim.show_market()
sim.sim_period(100)
# Out:
# Market Participants
# -------------------
# BUYERS
# ------
# buyer buyer 1 has values [161, 87, 60]
# buyer buyer 2 has values [182, 143, 89]
# buyer buyer 3 has values [165, 90, 58]
# buyer buyer 4 has values [172, 78, 74]
# --------
# SELLERS
# -------
# seller seller 1 has costs [55, 56, 166]
# seller seller 2 has costs [94, 112, 181]
# seller seller 3 has costs [41, 66, 122]
# seller seller 4 has costs [92, 118, 144]
# When Orange Market is in equilibrium we have:
# equilibrium price    = 92 - 94
# equilibrium quantity = 5
# maximum surplus      = 513
#
#
#  Order Book for Orange Market
# 1 start bid 0:Orange Market
# 2 start ask 999:Orange Market
# 3 standing bid 59:buyer 2
# 4 standing bid 92:buyer 3
# 5 standing bid 152:buyer 2
# 6 standing bid 161:buyer 2
# 7 standing bid 181:buyer 2
# 8 standing ask 487:seller 3
# 9 contract ask 168:seller 4
# 10 start bid 0:Orange Market
# 11 start ask 999:Orange Market
# 12 standing ask 300:seller 2
# 13 standing bid 117:buyer 2
# 14 standing bid 141:buyer 4
# 15 standing bid 149:buyer 3
# 16 contract ask 119:seller 1
# 17 start bid 0:Orange Market
# 18 start ask 999:Orange Market
# 19 standing ask 186:seller 4
# 20 standing ask 137:seller 2
# 21 standing bid 5:buyer 3
# 22 standing ask 127:seller 4
# 23 standing ask 114:seller 3
# 24 standing bid 15:buyer 3
# 25 standing bid 93:buyer 4
# 26 standing bid 101:buyer 4
# 27 contract bid 118:buyer 4
# 28 start bid 0:Orange Market
# 29 start ask 999:Orange Market
# 30 standing ask 707:seller 2
# 31 standing ask 418:seller 3
# 32 standing bid 38:buyer 4
# 33 standing bid 49:buyer 3
# 34 standing ask 201:seller 4
# 35 standing ask 170:seller 1
# 36 standing ask 122:seller 3
# 37 standing bid 70:buyer 4
# 38 standing bid 92:buyer 1
# 39 standing bid 110:buyer 2
# 40 contract bid 126:buyer 1
# 41 start bid 0:Orange Market
# 42 start ask 999:Orange Market
# 43 standing bid 17:buyer 3
# 44 standing bid 84:buyer 3
# 45 standing ask 484:seller 3
# 46 standing ask 384:seller 2
# 47 standing ask 159:seller 4
# 48 standing ask 118:seller 1
# 49 standing ask 114:seller 2
# 50 contract bid 138:buyer 2
# 51 start bid 0:Orange Market
# 52 start ask 999:Orange Market
# 53 standing bid 87:buyer 1
# 54 rejected bid 87:buyer 2
# 55 rejected bid 87:buyer 3
# 56 standing ask 939:seller 2
# 57 standing bid 88:buyer 2
# 58 standing bid 90:buyer 3
# 59 standing ask 874:seller 4
# 60 standing ask 130:seller 3
# 61 rejected ask 130:seller 4
# 62 contract ask 60:seller 1
# 63 start bid 0:Orange Market
# 64 start ask 999:Orange Market
# 65 standing bid 57:buyer 1
# 66 standing ask 730:seller 3
# 67 standing bid 85:buyer 2
# 68 standing ask 339:seller 2
# 69 standing ask 195:seller 2
# 70 standing ask 133:seller 3
# 71 standing ask 124:seller 3
# 72 standing bid 87:buyer 1
# 73 standing bid 89:buyer 2
# 74 standing ask 122:seller 4
# 75 standing ask 118:seller 4
# 76 standing ask 117:seller 2
# 77 standing ask 114:seller 2
#
# Contracts
# (181, 'buyer 2', 'seller 4')
# (149, 'buyer 3', 'seller 1')
# (114, 'buyer 4', 'seller 3')
# (122, 'buyer 1', 'seller 3')
# (114, 'buyer 2', 'seller 2')
# (90, 'buyer 3', 'seller 1')
#
# actual surplus = 509, efficiency = 99.22027290448344
# (509, 99.22027290448344, 5, 92, 94)

# %%
import tournament

tourn = tournament.Tournament("tournament_name", 5000, 100)
tourn.eval_tournament()
# Out:
# Median Actual Surplus: 523.0
# Mean Actual Surplus: 525.5534
# Median Efficiency: 97.07981026369333
# Mean Efficiency: 95.37788395615713
